# %%
# notebooks/Phase0_Verify.ipynb
# 【当前执行：Phase 0 的任务5 - 验证输出】

import pickle
import pandas as pd

# 验证bags.pkl
with open('data/bags.pkl', 'rb') as f:
    bags = pickle.load(f)
print(f"总bag数: {len(bags)}")
print(f"第一个bag的keys: {bags[0].keys()}")
print(f"特征维度: {bags[0]['features'].shape}")  # 应为 [num_instances, 522]

# 验证数据分割比例
# train/val/test 应按 Ori_file_num 的 70/15/15 分割
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 8
#       5 import pandas as pd
#       7 # 验证bags.pkl
# ----> 8 with open('data/bags.pkl', 'rb') as f:
#       9     bags = pickle.load(f)
#      10 print(f"总bag数: {len(bags)}")
#
# File d:\Python_env\Dolphin\Lib\site-packages\IPython\core\interactiveshell.py:346, in _modified_open(file, *args, **kwargs)
#     339 if file in {0, 1, 2}:
#     340     raise ValueError(
#     341         f"IPython won't let you open fd={file} by default "
#     342         "as it is likely to crash IPython. If you know what you are doing, "
#     343         "you can use builtins' open."
#     344     )
# --> 346 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/bags.pkl'
