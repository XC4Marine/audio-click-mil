# %%
# Data Loader
from torch.utils.data import DataLoader
from dataset import MILBagDataset

dataset = MILBagDataset(
    root_dir=r"D:\Project_Github\audio_click_mil\processed_data"
)

loader = DataLoader(
    dataset,
    batch_size=4,      # ⚠️ 建议先小一点
    shuffle=True,
    num_workers=4,
    pin_memory=True
)

# 测试一批
for x, s, y in loader:
    print(x.shape)  # (B,60,1,128,128)
    print(s.shape)  # (B,60,1)
    print(y.shape)  # (B,1)
    break
# Out:
# d:\Project_Github\audio_click_mil\src\src\dataset.py:11: SyntaxWarning: invalid escape sequence '\P'
#   """
# d:\Python_env\Dolphin\Lib\site-packages\torch\utils\data\dataloader.py:1118: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# torch.Size([4, 60, 1, 128, 128])
# torch.Size([4, 60, 1])
# torch.Size([4, 1])
